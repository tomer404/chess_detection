# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
from google.colab import files
import zipfile, os


from ultralytics import YOLO
model = YOLO("yolo11m.pt")
results = model.train(
    data = "/content/drive/My Drive/chess rows.v5i.yolov11/data.yaml",
    epochs = 200,
    imgsz = 640,
    batch = 16,
    device = 0
)
metrics = model.val()
print(metrics.box.map)
print(metrics.box.map50, metrics.box.map75)

# %%
from google.colab import files
from google.colab import files
import shutil

shutil.make_archive("train_results_medium", 'zip', "/content/runs/detect/train2")

files.download("train_results_medium.zip")
